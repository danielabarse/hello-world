# %% [markdown]
# # Ejercicios de optimización escalar

# %% [markdown]
# **Para la siguientes funciones encuentre los puntos críticos, grafique y diga si éste se trata de un máximo o mínimo, local o global.**

# %% [markdown]
# $f(x)=1260+117x-9x^2$

# %%
import sympy as sp
import numpy as np

sp.var("x")

def f(x): 
    return 1260 + 117*x - 9*x**2


df = sp.diff(f(x), x)
pc = sp.solve(df, x) 
ddf = sp.diff(df, x)

# %%
pc
# Out:
# [13/2]

# %%
ddf
# Out:
# -18

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

x = np.linspace (-20, 30)
y = f(x)
6
plt.figure()
plt.plot(x, y)
plt.plot (pc[0], f(pc[0]), "*r", ms=10)

# %% [markdown]
# La función tiene un punto crítico en el -18. Este punto crítico es un punto máximo y goblal.

# %% [markdown]
# $f(x)=5+x+\frac{4}{x}$, para $x>0$

# %%
import sympy as sp
import numpy as np

sp.var("x")

def f(x): 
    return 5 + x + (4/x)


df = sp.diff(f(x), x)
pc = sp.solve(df, x) 
ddf = sp.diff(df, x)

# %%
f(x)
# Out:
# x + 5 + 4/x

# %%
pc
# Out:
# [-2, 2]

# %%
df
# Out:
# 1 - 4/x**2

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

x = np.linspace (-20, 30)
y = f(x)

plt.figure()
plt.plot(x, y)
plt.plot (pc[0], f(pc[0]), "*r", ms=10)

# %% [markdown]
# Esta función tiene un punto critico en -2, el cual es un punto mímino global

# %% [markdown]
# $f(x)=6-2x+\sqrt{18-2x^2}$, para $-3\leq x\leq 3$

# %%
import sympy as sp
import numpy as np

x = sp.var("x")

def f(x): 
    return 6 - 2*x + sp.sqrt(18-2*x**2)

df = sp.diff(f(x), x)
pc = sp.solve(df, x) 
ddf = sp.diff(df, x)
# Out:
# -sqrt(6)

# %%
f(x)
# Out:
# -2*x + sqrt(18 - 2*x**2) + 6

# %%
pc
# Out:
# [-sqrt(6)]

# %%
df
# Out:
# -2*x/sqrt(18 - 2*x**2) - 2

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

xn = np.linspace(-3,3)
yn = [f(val).evalf() for val in xn]

plt.figure()
plt.plot(xn, yn, label='f(x)')
for c in pc:
    plt.plot(c.evalf(), f(c).evalf(), "*r", ms=10,)

plt.legend()
plt.show()

# %% [markdown]
# La función tiene un punto máximo global en -2.45

# %% [markdown]
# $f(x)=\frac{1}{4}x^4+\frac{1}{3}x^3-x^2$ en el intervalo $[-3,1.7]$

# %%
import sympy as sp
import numpy as np

sp.var("x")

def f(x): 
    return 1/4*x**4 + 1/3*x**3 - x**2

df = sp.diff(f(x), x)
pc = sp.solve(df, x) 
ddf = sp.diff(df, x)

# %%
f(x)
# Out:
# 0.25*x**4 + 0.333333333333333*x**3 - x**2

# %%
pc
# Out:
# [-2.00000000000000, 0.0, 1.00000000000000]

# %%
ddf
# Out:
# 3.0*x**2 + 2.0*x - 2

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
xn = np.linspace(-3,1.7)

plt.figure()
plt.plot(xn, f(xn))
for c in pc:
    plt.plot(c, f(c), "*r", ms=10)

# %% [markdown]
# Está función cuenta con 3 puntos críticos. En primer punto crítico esta en -2 siendo un mínimo local. Esl siguiente esta en 0 como punto máximo global.  Y el último punto esta en 1 y como mínimo local.

# %% [markdown]
# ---
# **Resuelva los siguientes problemas usando la librería `SymPy`. Use celdas en `Markdown` para explicar su procedimiento.**

# %% [markdown]
# El perímetro de un triángulo isósceles es de $10 cm$. ¿Cuánto deben medir sus lados para que el volumen del cuerpo generado por la rotación del triángulo en torno a su base sea el mayor posible? (Volumen de un cono $= \frac{1}{3}\pi r^2 h$, donde $r$ es el radio de la base y $h$ la altura del cono).

# %%
import sympy as sp

def volumen_cono(r, h):
    return (1/3) * sp.pi * r**2 * h

def maximizar_volumen():
    perimetro = 10

    a = (perimetro - 10) / -4

    b = perimetro / 2

    h = sp.sqrt(a**2 - (b/2)**2)

    r = b / 2

    volumen = volumen_cono(r, h)

    return a, b, h, r, volumen

lado_a, lado_b, altura_h, radio_r, volumen_maximo = maximizar_volumen()

# %%
lado_a
# Out:
# -0.0

# %%
lado_b
# Out:
# 5.0

# %%
altura_h
# Out:
# 2.5*I

# %%
radio_r
# Out:
# 2.5

# %%
volumen_maximo
# Out:
# 5.20833333333333*I*pi

# %% [markdown]
# la base tendra que ser de 5 cms y la altura de 2.5 para que el volumen máximo sea de 5.21 ipi

# %% [markdown]
# Disponemos de una barra de aluminio de 6 metros para construir una portería de fútbol. Si queremos que el área de la portería sea máxima, ¿cuánto deben medir los postes y el travesaño?

# %%
import sympy as sp

def area_porteria(postes, travesaño):
    return postes * (6 - 2 * postes) * travesaño

def maximizar_area_porteria():
    perimetro = 6  # Longitud total de la barra de aluminio

    postes = sp.Symbol('postes')
    travesaño = perimetro - 2 * postes

    area = area_porteria(postes, travesaño)

   
    darea = sp.diff(area, postes)

    solucion_postes = sp.solve(darea, postes)

    solucion_travesaño = [perimetro - 2 * p for p in solucion_postes]

    max_area = None
    for p, t in zip(solucion_postes, solucion_travesaño):
        area_actual = area_porteria(p, t)
        if max_area is None or area_actual > max_area:
            max_area = area_actual

    return solucion_postes, solucion_travesaño, max_area

postes_op, travesaño_op, area_max = maximizar_area_porteria()

# %%
postes_optimos
# Out:
# [1, 3]

# %%
travesaño_optimo
# Out:
# [4, 0]

# %%
area_maxima
# Out:
# 16

# %% [markdown]
# Tomamos los valores en x de lo resultados, ya que son los que nos interesan. Dando así como resultasdo un poste de 1 metro y un travesaño de 4 metros para poder tener un área máxima de  metros cuadrados
